# %%
import pandas as pd
import sqlite3


file="est15us.csv"

state_15=pd.read_csv(file)
state_15
# Out:
#             Table with column headers in rows 3 and 4   Unnamed: 1  \
# 0   2015 Poverty and Median Household Income Estim...          NaN
# 1                              Geographic Information          NaN
# 2                                     State FIPS Code  Postal Code
# 3                                                  00           US
# 4                                                  01           AL
# 5                                                  02           AK
# 6                                                  04           AZ
# 7                                                  05           AR
# 8                                                  06           CA
# 9                                                  08           CO
# 10                                                 09           CT
# 11                                                 10           DE
# 12                                                 11           DC
# ...

# %%
state_15=state_15.drop(state_15.index[0])
state_15.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 1                    Geographic Information          NaN            NaN
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 1                    All Ages                 NaN                 NaN
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  46,153,077          45,878,016          46,428,138
# 4                     875,853             859,781             891,925
# 5                      74,941              71,399              78,483
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_15=state_15.drop(state_15.index[0])
state_15.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
# 6                                        04           AZ        Arizona
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  46,153,077          45,878,016          46,428,138
# 4                     875,853             859,781             891,925
# 5                      74,941              71,399              78,483
# 6                   1,159,046           1,136,666           1,181,426
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_15=state_15.drop(state_15.index[0])
state_15.head()
# Out:
#   Table with column headers in rows 3 and 4 Unnamed: 1     Unnamed: 2  \
# 3                                        00         US  United States
# 4                                        01         AL        Alabama
# 5                                        02         AK         Alaska
# 6                                        04         AZ        Arizona
# 7                                        05         AR       Arkansas
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 3  46,153,077  45,878,016  46,428,138       14.7       14.6       14.8
# 4     875,853     859,781     891,925       18.5       18.2       18.8
# 5      74,941      71,399      78,483       10.4        9.9       10.9
# 6   1,159,046   1,136,666   1,181,426       17.4       17.1       17.7
# 7     540,733     528,756     552,710       18.7       18.3       19.1
#
#    Unnamed: 9  ... Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...

# %%
state_15_df=pd.DataFrame({"abbreviation":state_15["Unnamed: 1"],
                                    "state":state_15["Unnamed: 2"],
                                    "poverty_percent_15":state_15["Unnamed: 6"],
                                    "median_household_income_15":state_15["Unnamed: 21"]
    
})

state_15_df.head()
# Out:
#   abbreviation          state poverty_percent_15 median_household_income_15
# 3           US  United States               14.7                     55,775
# 4           AL        Alabama               18.5                     44,833
# 5           AK         Alaska               10.4                     73,391
# 6           AZ        Arizona               17.4                     51,473
# 7           AR       Arkansas               18.7                     42,046

# %%
state_15_df.to_csv("income_poverty_STATE_15.csv")

# %%
file="est16us.csv"
state_16=pd.read_csv(file)
state_16.head()
# Out:
#            Table with column headers in rows 3 and 4   Unnamed: 1  \
# 0  2016 Poverty and Median Household Income Estim...          NaN
# 1                             Geographic Information          NaN
# 2                                    State FIPS Code  Postal Code
# 3                                                 00           US
# 4                                                 01           AL
#
#       Unnamed: 2                  Unnamed: 3          Unnamed: 4  \
# 0            NaN                         NaN                 NaN
# 1            NaN                    All Ages                 NaN
# 2           Name  Poverty Estimate, All Ages  90% CI Lower Bound
# 3  United States                  44,268,996          44,022,086
# 4        Alabama                     814,197             796,927
#
#            Unnamed: 5                 Unnamed: 6          Unnamed: 7  \
# 0                 NaN                        NaN                 NaN
# ...

# %%
state_16=state_16.drop(state_16.index[0])
state_16.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 1                    Geographic Information          NaN            NaN
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 1                    All Ages                 NaN                 NaN
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  44,268,996          44,022,086          44,515,906
# 4                     814,197             796,927             831,467
# 5                      71,916              67,813              76,019
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_16=state_16.drop(state_16.index[0])
state_16.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
# 6                                        04           AZ        Arizona
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  44,268,996          44,022,086          44,515,906
# 4                     814,197             796,927             831,467
# 5                      71,916              67,813              76,019
# 6                   1,107,153           1,086,482           1,127,824
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_16=state_16.drop(state_16.index[0])
state_16.head()
# Out:
#   Table with column headers in rows 3 and 4 Unnamed: 1     Unnamed: 2  \
# 3                                        00         US  United States
# 4                                        01         AL        Alabama
# 5                                        02         AK         Alaska
# 6                                        04         AZ        Arizona
# 7                                        05         AR       Arkansas
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 3  44,268,996  44,022,086  44,515,906       14.0       13.9       14.1
# 4     814,197     796,927     831,467       17.2       16.8       17.6
# 5      71,916      67,813      76,019        9.9        9.3       10.5
# 6   1,107,153   1,086,482   1,127,824       16.4       16.1       16.7
# 7     497,388     485,180     509,596       17.2       16.8       17.6
#
#    Unnamed: 9  ... Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...

# %%
state_16_df=pd.DataFrame({"abbreviation":state_16["Unnamed: 1"],
                                    "state":state_16["Unnamed: 2"],
                                    "poverty_percent_16":state_16["Unnamed: 6"],
                                    "median_household_income_16":state_16["Unnamed: 21"]
    
})

state_16_df.head()
# Out:
#   abbreviation          state poverty_percent_16 median_household_income_16
# 3           US  United States               14.0                     57,617
# 4           AL        Alabama               17.2                     46,309
# 5           AK         Alaska                9.9                     76,144
# 6           AZ        Arizona               16.4                     53,481
# 7           AR       Arkansas               17.2                     44,406

# %%
state_16_df.to_csv("income_poverty_STATE_16.csv")

# %%
file="est17us.csv"
state_17=pd.read_csv(file)
state_17.head()
# Out:
#            Table with column headers in rows 3 and 4   Unnamed: 1  \
# 0  2017 Poverty and Median Household Income Estim...          NaN
# 1                             Geographic Information          NaN
# 2                                    State FIPS Code  Postal Code
# 3                                                 00           US
# 4                                                 01           AL
#
#       Unnamed: 2                  Unnamed: 3          Unnamed: 4  \
# 0            NaN                         NaN                 NaN
# 1            NaN                    All Ages                 NaN
# 2           Name  Poverty Estimate, All Ages  90% CI Lower Bound
# 3  United States                  42,583,651          42,342,619
# 4        Alabama                     802,263             784,517
#
#            Unnamed: 5                 Unnamed: 6          Unnamed: 7  \
# 0                 NaN                        NaN                 NaN
# ...

# %%
state_17=state_17.drop(state_17.index[0])
state_17.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 1                    Geographic Information          NaN            NaN
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 1                    All Ages                 NaN                 NaN
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  42,583,651          42,342,619          42,824,683
# 4                     802,263             784,517             820,009
# 5                      79,428              75,273              83,583
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_17=state_17.drop(state_17.index[0])
state_17.head()
# Out:
#   Table with column headers in rows 3 and 4   Unnamed: 1     Unnamed: 2  \
# 2                           State FIPS Code  Postal Code           Name
# 3                                        00           US  United States
# 4                                        01           AL        Alabama
# 5                                        02           AK         Alaska
# 6                                        04           AZ        Arizona
#
#                    Unnamed: 3          Unnamed: 4          Unnamed: 5  \
# 2  Poverty Estimate, All Ages  90% CI Lower Bound  90% CI Upper Bound
# 3                  42,583,651          42,342,619          42,824,683
# 4                     802,263             784,517             820,009
# 5                      79,428              75,273              83,583
# 6                   1,023,337           1,002,773           1,043,901
#
#                   Unnamed: 6          Unnamed: 7          Unnamed: 8  \
# ...

# %%
state_17=state_17.drop(state_17.index[0])
state_17.head()
# Out:
#   Table with column headers in rows 3 and 4 Unnamed: 1     Unnamed: 2  \
# 3                                        00         US  United States
# 4                                        01         AL        Alabama
# 5                                        02         AK         Alaska
# 6                                        04         AZ        Arizona
# 7                                        05         AR       Arkansas
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 3  42,583,651  42,342,619  42,824,683       13.4       13.3       13.5
# 4     802,263     784,517     820,009       16.9       16.5       17.3
# 5      79,428      75,273      83,583       11.0       10.4       11.6
# 6   1,023,337   1,002,773   1,043,901       14.9       14.6       15.2
# 7     475,883     463,966     487,800       16.3       15.9       16.7
#
#    Unnamed: 9  ... Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...

# %%
state_17_df=pd.DataFrame({"abbreviation":state_17["Unnamed: 1"],
                                    "state":state_17["Unnamed: 2"],
                                    "poverty_percent_17":state_17["Unnamed: 6"],
                                    "median_household_income_17":state_17["Unnamed: 21"]
    
})

state_17_df.head()
# Out:
#   abbreviation          state poverty_percent_17 median_household_income_17
# 3           US  United States               13.4                     60,336
# 4           AL        Alabama               16.9                     48,193
# 5           AK         Alaska               11.0                     74,058
# 6           AZ        Arizona               14.9                     56,508
# 7           AR       Arkansas               16.3                     45,916

# %%
state_17_df.to_csv("income_poverty_STATE_17.csv")

# %%
state_15_16 = pd.merge(state_15_df, state_16_df, on="state")
state_15_16.head()
# Out:
#   abbreviation_x          state poverty_percent_15 median_household_income_15  \
# 0             US  United States               14.7                     55,775
# 1             AL        Alabama               18.5                     44,833
# 2             AK         Alaska               10.4                     73,391
# 3             AZ        Arizona               17.4                     51,473
# 4             AR       Arkansas               18.7                     42,046
#
#   abbreviation_y poverty_percent_16 median_household_income_16
# 0             US               14.0                     57,617
# 1             AL               17.2                     46,309
# 2             AK                9.9                     76,144
# 3             AZ               16.4                     53,481
# 4             AR               17.2                     44,406

# %%
state_15_16=state_15_16.drop("abbreviation_y",1)

# %%
state_15_16.rename(columns={"abbreviation_x":"abbreviation"})
# Out:
#    abbreviation                 state poverty_percent_15  \
# 0            US         United States               14.7
# 1            AL               Alabama               18.5
# 2            AK                Alaska               10.4
# 3            AZ               Arizona               17.4
# 4            AR              Arkansas               18.7
# 5            CA            California               15.4
# 6            CO              Colorado               11.5
# 7            CT           Connecticut               10.6
# 8            DE              Delaware               12.6
# 9            DC  District of Columbia               17.7
# 10           FL               Florida               15.8
# 11           GA               Georgia               17.2
# 12           HI                Hawaii               10.7
# 13           ID                 Idaho               14.7
# 14           IL              Illinois               13.6
# ...

# %%
merge_15_16_17=pd.merge(state_15_16,state_17_df, on="state")
merge_15_16_17.head()
# Out:
#   abbreviation_x          state poverty_percent_15 median_household_income_15  \
# 0             US  United States               14.7                     55,775
# 1             AL        Alabama               18.5                     44,833
# 2             AK         Alaska               10.4                     73,391
# 3             AZ        Arizona               17.4                     51,473
# 4             AR       Arkansas               18.7                     42,046
#
#   poverty_percent_16 median_household_income_16 abbreviation  \
# 0               14.0                     57,617           US
# 1               17.2                     46,309           AL
# 2                9.9                     76,144           AK
# 3               16.4                     53,481           AZ
# 4               17.2                     44,406           AR
#
#   poverty_percent_17 median_household_income_17
# 0               13.4                     60,336
# ...

# %%
merge_15_16_17=merge_15_16_17.drop("abbreviation",1)

# %%
state_final_merge=merge_15_16_17.rename(columns={"abbreviation_x":"abbreviation"})

# %%
state_final_merge.reset_index(inplace=True)
state_final_merge.head()
# Out:
#    index abbreviation          state poverty_percent_15  \
# 0      0           US  United States               14.7
# 1      1           AL        Alabama               18.5
# 2      2           AK         Alaska               10.4
# 3      3           AZ        Arizona               17.4
# 4      4           AR       Arkansas               18.7
#
#   median_household_income_15 poverty_percent_16 median_household_income_16  \
# 0                     55,775               14.0                     57,617
# 1                     44,833               17.2                     46,309
# 2                     73,391                9.9                     76,144
# 3                     51,473               16.4                     53,481
# 4                     42,046               17.2                     44,406
#
#   poverty_percent_17 median_household_income_17
# 0               13.4                     60,336
# 1               16.9                     48,193
# ...

# %%
state_final_merge=state_final_merge.drop("index",1)

# %%
# state_final_merge=state_final_merge.drop([0,9])
state_final_merge.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-125508a2758c> in <module>
# ----> 1 state_final_merge=state_final_merge.drop([0,9])
#       2 state_final_merge.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
state_final_merge['id']= range(1, 1+len(state_final_merge))

# %%
state_final_df=state_final_merge[['id','abbreviation','state','poverty_percent_15','median_household_income_15',
                                                       'poverty_percent_16','median_household_income_16','poverty_percent_17',
                                                      'median_household_income_17']]
state_final_df
# Out:
#     id abbreviation           state poverty_percent_15  \
# 1    1           AL         Alabama               18.5
# 2    2           AK          Alaska               10.4
# 3    3           AZ         Arizona               17.4
# 4    4           AR        Arkansas               18.7
# 5    5           CA      California               15.4
# 6    6           CO        Colorado               11.5
# 7    7           CT     Connecticut               10.6
# 8    8           DE        Delaware               12.6
# 10   9           FL         Florida               15.8
# 11  10           GA         Georgia               17.2
# 12  11           HI          Hawaii               10.7
# 13  12           ID           Idaho               14.7
# 14  13           IL        Illinois               13.6
# 15  14           IN         Indiana               14.4
# 16  15           IA            Iowa               12.1
# 17  16           KS          Kansas               12.9
# ...

# %%
file='statelatlong.csv'
latlong_df=pd.read_csv(file)
latlong_df
# Out:
#    State   Latitude   Longitude                  City
# 0     AL  32.601011  -86.680736               Alabama
# 1     AK  61.302501 -158.775020                Alaska
# 2     AZ  34.168219 -111.930907               Arizona
# 3     AR  34.751928  -92.131378              Arkansas
# 4     CA  37.271875 -119.270415            California
# 5     CO  38.997934 -105.550567              Colorado
# 6     CT  41.518784  -72.757507           Connecticut
# 7     DE  39.145251  -75.418921              Delaware
# 8     DC  38.899349  -77.014567  District of Columbia
# 9     FL  27.975728  -83.833017               Florida
# 10    GA  32.678125  -83.222976               Georgia
# 11    HI  20.460000 -157.505000                Hawaii
# 12    ID  45.494576 -114.142430                 Idaho
# 13    IL  39.739318  -89.504139              Illinois
# 14    IN  39.766219  -86.441277               Indiana
# 15    IA  41.938317  -93.389798                  Iowa
# ...

# %%
latlong_df=latlong_df.drop([8])

# %%
latlong_df
# Out:
#    State   Latitude   Longitude            City
# 0     AL  32.601011  -86.680736         Alabama
# 1     AK  61.302501 -158.775020          Alaska
# 2     AZ  34.168219 -111.930907         Arizona
# 3     AR  34.751928  -92.131378        Arkansas
# 4     CA  37.271875 -119.270415      California
# 5     CO  38.997934 -105.550567        Colorado
# 6     CT  41.518784  -72.757507     Connecticut
# 7     DE  39.145251  -75.418921        Delaware
# 9     FL  27.975728  -83.833017         Florida
# 10    GA  32.678125  -83.222976         Georgia
# 11    HI  20.460000 -157.505000          Hawaii
# 12    ID  45.494576 -114.142430           Idaho
# 13    IL  39.739318  -89.504139        Illinois
# 14    IN  39.766219  -86.441277         Indiana
# 15    IA  41.938317  -93.389798            Iowa
# 16    KS  38.498779  -98.320078          Kansas
# 17    KY  37.822294  -85.768240        Kentucky
# 18    LA  30.973377  -91.429910       Louisiana
# 19    ME  45.218513  -69.014866           Maine
# ...

# %%
# latlong_df=latlong_df.drop(columns=['State'])
latlong_df.head()
# Out:
#     Latitude   Longitude        City
# 0  32.601011  -86.680736     Alabama
# 1  61.302501 -158.775020      Alaska
# 2  34.168219 -111.930907     Arizona
# 3  34.751928  -92.131378    Arkansas
# 4  37.271875 -119.270415  California

# %%
latlong_df=latlong_df.rename(columns={"City":"state","Latitude":"latitude","Longitude":"longitude"})

# %%
state_final_df=pd.merge(state_final_df,latlong_df,on='state')

# %%
state_final_df
# Out:
#     id abbreviation           state poverty_percent_15  \
# 0    1           AL         Alabama               18.5
# 1    2           AK          Alaska               10.4
# 2    3           AZ         Arizona               17.4
# 3    4           AR        Arkansas               18.7
# 4    5           CA      California               15.4
# 5    6           CO        Colorado               11.5
# 6    7           CT     Connecticut               10.6
# 7    8           DE        Delaware               12.6
# 8    9           FL         Florida               15.8
# 9   10           GA         Georgia               17.2
# 10  11           HI          Hawaii               10.7
# 11  12           ID           Idaho               14.7
# 12  13           IL        Illinois               13.6
# 13  14           IN         Indiana               14.4
# 14  15           IA            Iowa               12.1
# 15  16           KS          Kansas               12.9
# ...

# %%
state_final_df.to_csv("state_final.csv")

# %% [markdown]
# # SQLite db

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
state_final_df.to_sql('state_income_poverty', con=engine)
engine.execute("SELECT * FROM state_income_poverty").fetchall()
# Out:
# [(0, 1, 'AL', 'Alabama', '18.5', '44,833', '17.2', '46,309', '16.9', '48,193', 32.601011199999995, -86.6807365),
#  (1, 2, 'AK', 'Alaska', '10.4', '73,391', '9.9', '76,144', '11.0', '74,058', 61.3025006, -158.7750198),
#  (2, 3, 'AZ', 'Arizona', '17.4', '51,473', '16.4', '53,481', '14.9', '56,508', 34.1682185, -111.930907),
#  (3, 4, 'AR', 'Arkansas', '18.7', '42,046', '17.2', '44,406', '16.3', '45,916', 34.7519275, -92.13137840000002),
#  (4, 5, 'CA', 'California', '15.4', '64,483', '14.4', '67,715', '13.3', '71,785', 37.2718745, -119.2704153),
#  (5, 6, 'CO', 'Colorado', '11.5', '63,945', '11.0', '65,718', '10.3', '69,113', 38.9979339, -105.55056699999999),
#  (6, 7, 'CT', 'Connecticut', '10.6', '71,333', '9.9', '73,380', '9.7', '74,428', 41.518783500000005, -72.75750699999999),
#  (7, 8, 'DE', 'Delaware', '12.6', '61,327', '11.8', '62,112', '13.0', '64,085', 39.145251, -75.41892059999999),
# ...

# %%
connection_string = "postgres:postgres@localhost:5432/income_poverty"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['income_poverty', 'state_income_poverty']

# %%
state_final_df.to_sql(name='state_income_poverty', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from state_income_poverty', con=engine).head()
# Out:
#    id abbreviation       state poverty_percent_15 median_household_income_15  \
# 0   1           AL     Alabama               18.5                     44,833
# 1   2           AK      Alaska               10.4                     73,391
# 2   3           AZ     Arizona               17.4                     51,473
# 3   4           AR    Arkansas               18.7                     42,046
# 4   5           CA  California               15.4                     64,483
#
#   poverty_percent_16 median_household_income_16 poverty_percent_17  \
# 0               17.2                     46,309               16.9
# 1                9.9                     76,144               11.0
# 2               16.4                     53,481               14.9
# 3               17.2                     44,406               16.3
# 4               14.4                     67,715               13.3
#
#   median_household_income_17   latitude   longitude
# ...

# %%
conn = sqlite3.connect('state_income_poverty.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE state_income_poverty (id int primary key, abbreviation number, state number, poverty_percent_15 number, median_household_income_15 number, poverty_percent_16 number, median_household_income_16 number, poverty_percent_17 number, median_household_income_17 number, latitude number, longitude number )')
conn.commit()

# %%
state_final_df.to_sql('state_income_poverty', conn, if_exists='replace', index = False)

# %%
c.execute('''  
SELECT * FROM state_income_poverty
          ''')

# %%
for row in c.fetchall():
    print (row)
# Out:
# (1, 'AL', 'Alabama', '18.5', '44,833', '17.2', '46,309', '16.9', '48,193', 32.601011199999995, -86.6807365)
# (2, 'AK', 'Alaska', '10.4', '73,391', '9.9', '76,144', '11.0', '74,058', 61.3025006, -158.7750198)
# (3, 'AZ', 'Arizona', '17.4', '51,473', '16.4', '53,481', '14.9', '56,508', 34.1682185, -111.930907)
# (4, 'AR', 'Arkansas', '18.7', '42,046', '17.2', '44,406', '16.3', '45,916', 34.7519275, -92.13137840000002)
# (5, 'CA', 'California', '15.4', '64,483', '14.4', '67,715', '13.3', '71,785', 37.2718745, -119.2704153)
# (6, 'CO', 'Colorado', '11.5', '63,945', '11.0', '65,718', '10.3', '69,113', 38.9979339, -105.55056699999999)
# (7, 'CT', 'Connecticut', '10.6', '71,333', '9.9', '73,380', '9.7', '74,428', 41.518783500000005, -72.75750699999999)
# (8, 'DE', 'Delaware', '12.6', '61,327', '11.8', '62,112', '13.0', '64,085', 39.145251, -75.41892059999999)
# (9, 'FL', 'Florida', '15.8', '49,416', '14.8', '50,857', '14.1', '52,582', 27.9757279, -83.8330166)
# ...
